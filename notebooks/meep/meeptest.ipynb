# %% [markdown]
# Temp file for testing `meep` functionality

# %%
import numpy as np
import matplotlib.pyplot as plt
import meep as mp

cell = mp.Vector3(16,8,0)   # simulation space

geometry = [mp.Block(mp.Vector3(1e20,1,1e20),   # waveguide
                     center=mp.Vector3(0,0),
                     material=mp.Medium(epsilon=12))]

sources = [mp.Source(mp.ContinuousSource(frequency=0.15),
                     component=mp.Ez,
                     center=mp.Vector3(-7,0))]

pml_layers = [mp.PML(1.0)]
resolution = 100

sim = mp.Simulation(cell_size=cell,
                    boundary_layers=pml_layers,
                    geometry=geometry,
                    sources=sources,
                    resolution=resolution)

sim.run(until=200)
# Out:
# -----------
# Initializing structure...
# Meep progress: 0.705/200.0 = 0.4% done in 4.0s, 1138.0s to go
# Meep progress: 1.45/200.0 = 0.7% done in 8.0s, 1100.6s to go
# Meep progress: 2.215/200.0 = 1.1% done in 12.0s, 1075.5s to go
# Meep progress: 2.96/200.0 = 1.5% done in 16.1s, 1069.3s to go
# Meep progress: 3.715/200.0 = 1.9% done in 20.1s, 1060.2s to go
# Meep progress: 4.45/200.0 = 2.2% done in 24.1s, 1058.4s to go
# Meep progress: 5.175/200.0 = 2.6% done in 28.1s, 1058.0s to go
# Meep progress: 5.8950000000000005/200.0 = 2.9% done in 32.1s, 1057.9s to go
# Meep progress: 6.61/200.0 = 3.3% done in 36.2s, 1057.8s to go
# Meep progress: 7.32/200.0 = 3.7% done in 40.2s, 1057.5s to go
# Meep progress: 8.0/200.0 = 4.0% done in 44.2s, 1060.9s to go
# Meep progress: 8.66/200.0 = 4.3% done in 48.2s, 1065.6s to go
# Meep progress: 9.31/200.0 = 4.7% done in 52.2s, 1070.2s to go
# Meep progress: 9.995000000000001/200.0 = 5.0% done in 56.3s, 1069.8s to go
# Meep progress: 10.61/200.0 = 5.3% done in 60.3s, 1076.3s to go
# Meep progress: 11.22/200.0 = 5.6% done in 64.3s, 1082.2s to go
# Meep progress: 11.875/200.0 = 5.9% done in 68.3s, 1082.7s to go
# Meep progress: 12.6/200.0 = 6.3% done in 72.3s, 1076.1s to go
# Meep progress: 13.3/200.0 = 6.7% done in 76.4s, 1071.9s to go
# Meep progress: 14.035/200.0 = 7.0% done in 80.4s, 1064.9s to go
# Meep progress: 14.74/200.0 = 7.4% done in 84.4s, 1060.6s to go
# Meep progress: 15.455/200.0 = 7.7% done in 88.4s, 1055.5s to go
# Meep progress: 16.055/200.0 = 8.0% done in 92.4s, 1058.7s to go
# Meep progress: 16.6/200.0 = 8.3% done in 96.4s, 1065.2s to go
# Meep progress: 17.235/200.0 = 8.6% done in 100.4s, 1065.1s to go
# Meep progress: 17.87/200.0 = 8.9% done in 104.4s, 1064.5s to go
# Meep progress: 18.51/200.0 = 9.3% done in 108.5s, 1063.4s to go
# Meep progress: 19.145/200.0 = 9.6% done in 112.5s, 1062.5s to go
# Meep progress: 19.805/200.0 = 9.9% done in 116.5s, 1059.8s to go
# Meep progress: 20.400000000000002/200.0 = 10.2% done in 120.5s, 1060.8s to go
# Meep progress: 21.035/200.0 = 10.5% done in 124.5s, 1059.2s to go
# Meep progress: 21.78/200.0 = 10.9% done in 128.5s, 1051.6s to go
# Meep progress: 22.465/200.0 = 11.2% done in 132.5s, 1047.4s to go
# Meep progress: 23.155/200.0 = 11.6% done in 136.6s, 1042.9s to go
# Meep progress: 23.86/200.0 = 11.9% done in 140.6s, 1037.7s to go
# Meep progress: 24.535/200.0 = 12.3% done in 144.6s, 1033.9s to go
# Meep progress: 25.22/200.0 = 12.6% done in 148.6s, 1029.7s to go
# Meep progress: 25.92/200.0 = 13.0% done in 152.6s, 1024.8s to go
# Meep progress: 26.580000000000002/200.0 = 13.3% done in 156.6s, 1021.7s to go
# Meep progress: 27.125/200.0 = 13.6% done in 160.6s, 1023.6s to go
# Meep progress: 27.765/200.0 = 13.9% done in 164.6s, 1021.2s to go
# Meep progress: 28.47/200.0 = 14.2% done in 168.6s, 1016.0s to go
# Meep progress: 29.175/200.0 = 14.6% done in 172.6s, 1010.8s to go
# Meep progress: 29.93/200.0 = 15.0% done in 176.6s, 1003.7s to go
# Meep progress: 30.035/200.0 = 15.0% done in 256.7s, 1452.7s to go
# Meep progress: 30.61/200.0 = 15.3% done in 260.7s, 1442.7s to go
# Meep progress: 31.27/200.0 = 15.6% done in 264.7s, 1428.5s to go
# Meep progress: 31.92/200.0 = 16.0% done in 268.8s, 1415.2s to go
# Meep progress: 32.58/200.0 = 16.3% done in 272.8s, 1401.7s to go
# Meep progress: 33.230000000000004/200.0 = 16.6% done in 276.8s, 1389.2s to go
# Meep progress: 33.835/200.0 = 16.9% done in 280.8s, 1379.1s to go
# Meep progress: 34.39/200.0 = 17.2% done in 284.8s, 1371.6s to go
# Meep progress: 35.035000000000004/200.0 = 17.5% done in 288.8s, 1360.0s to go
# Meep progress: 35.71/200.0 = 17.9% done in 292.8s, 1347.3s to go
# Meep progress: 36.35/200.0 = 18.2% done in 296.9s, 1336.5s to go
# Meep progress: 37.01/200.0 = 18.5% done in 300.9s, 1325.1s to go
# Meep progress: 37.615/200.0 = 18.8% done in 304.9s, 1316.2s to go
# Meep progress: 38.21/200.0 = 19.1% done in 308.9s, 1307.9s to go
# Meep progress: 38.755/200.0 = 19.4% done in 312.9s, 1302.0s to go
# Meep progress: 39.375/200.0 = 19.7% done in 316.9s, 1292.9s to go
# Meep progress: 39.935/200.0 = 20.0% done in 321.0s, 1286.4s to go
# Meep progress: 40.57/200.0 = 20.3% done in 325.0s, 1277.1s to go
# Meep progress: 41.22/200.0 = 20.6% done in 329.0s, 1267.3s to go
# Meep progress: 41.765/200.0 = 20.9% done in 333.0s, 1261.7s to go
# Meep progress: 42.43/200.0 = 21.2% done in 337.0s, 1251.6s to go
# Meep progress: 43.095/200.0 = 21.5% done in 341.1s, 1241.8s to go
# Meep progress: 43.79/200.0 = 21.9% done in 345.1s, 1230.9s to go
# Meep progress: 44.36/200.0 = 22.2% done in 349.1s, 1224.8s to go
# Meep progress: 44.87/200.0 = 22.4% done in 353.1s, 1220.7s to go
# Meep progress: 45.47/200.0 = 22.7% done in 357.1s, 1213.6s to go
# Meep progress: 46.195/200.0 = 23.1% done in 361.1s, 1202.3s to go
# Meep progress: 46.875/200.0 = 23.4% done in 365.1s, 1192.8s to go
# Meep progress: 47.415/200.0 = 23.7% done in 369.2s, 1188.0s to go
# Meep progress: 48.01/200.0 = 24.0% done in 373.2s, 1181.4s to go
# Meep progress: 48.555/200.0 = 24.3% done in 377.2s, 1176.5s to go
# Meep progress: 49.195/200.0 = 24.6% done in 381.2s, 1168.5s to go
# Meep progress: 49.82/200.0 = 24.9% done in 385.2s, 1161.2s to go
# Meep progress: 50.5/200.0 = 25.2% done in 389.2s, 1152.3s to go
# Meep progress: 51.25/200.0 = 25.6% done in 393.2s, 1141.4s to go
# Meep progress: 51.935/200.0 = 26.0% done in 397.3s, 1132.6s to go
# Meep progress: 52.45/200.0 = 26.2% done in 401.3s, 1128.9s to go
# Meep progress: 52.955/200.0 = 26.5% done in 405.3s, 1125.5s to go
# Meep progress: 53.545/200.0 = 26.8% done in 409.3s, 1119.6s to go
# Meep progress: 54.15/200.0 = 27.1% done in 413.4s, 1113.4s to go
# Meep progress: 54.775/200.0 = 27.4% done in 417.4s, 1106.6s to go
# Meep progress: 55.495000000000005/200.0 = 27.7% done in 421.4s, 1097.4s to go
# Meep progress: 56.175000000000004/200.0 = 28.1% done in 425.4s, 1089.3s to go
# Meep progress: 56.74/200.0 = 28.4% done in 429.5s, 1084.3s to go
# Meep progress: 57.34/200.0 = 28.7% done in 433.5s, 1078.4s to go
# Meep progress: 57.985/200.0 = 29.0% done in 437.5s, 1071.4s to go
# Meep progress: 58.67/200.0 = 29.3% done in 441.5s, 1063.5s to go
# Meep progress: 59.355000000000004/200.0 = 29.7% done in 445.5s, 1055.7s to go
# Meep progress: 59.985/200.0 = 30.0% done in 449.5s, 1049.3s to go
# Meep progress: 60.645/200.0 = 30.3% done in 453.5s, 1042.2s to go
# Meep progress: 61.33/200.0 = 30.7% done in 457.6s, 1034.6s to go
# Meep progress: 62.0/200.0 = 31.0% done in 461.6s, 1027.4s to go
# Meep progress: 62.620000000000005/200.0 = 31.3% done in 465.6s, 1021.5s to go
# Meep progress: 63.155/200.0 = 31.6% done in 469.6s, 1017.6s to go
# Meep progress: 63.715/200.0 = 31.9% done in 473.6s, 1013.1s to go
# Meep progress: 64.34/200.0 = 32.2% done in 477.6s, 1007.1s to go
# Meep progress: 64.905/200.0 = 32.5% done in 481.7s, 1002.5s to go
# Meep progress: 65.505/200.0 = 32.8% done in 485.7s, 997.2s to go
# Meep progress: 66.14/200.0 = 33.1% done in 489.7s, 991.1s to go
# Meep progress: 66.785/200.0 = 33.4% done in 493.7s, 984.7s to go
# Meep progress: 67.49/200.0 = 33.7% done in 497.7s, 977.2s to go
# Meep progress: 68.1/200.0 = 34.0% done in 501.7s, 971.8s to go
# Meep progress: 68.68/200.0 = 34.3% done in 505.8s, 967.0s to go
# Meep progress: 69.265/200.0 = 34.6% done in 509.8s, 962.2s to go
# Meep progress: 69.84/200.0 = 34.9% done in 513.8s, 957.6s to go
# Meep progress: 70.375/200.0 = 35.2% done in 517.8s, 953.8s to go
# Meep progress: 71.01/200.0 = 35.5% done in 521.9s, 947.9s to go
# Meep progress: 71.63/200.0 = 35.8% done in 525.9s, 942.4s to go
# Meep progress: 72.275/200.0 = 36.1% done in 529.9s, 936.4s to go
# Meep progress: 72.875/200.0 = 36.4% done in 533.9s, 931.3s to go
# Meep progress: 73.465/200.0 = 36.7% done in 537.9s, 926.5s to go
# Meep progress: 74.07000000000001/200.0 = 37.0% done in 541.9s, 921.3s to go
# Meep progress: 74.65/200.0 = 37.3% done in 545.9s, 916.7s to go
# Meep progress: 75.16/200.0 = 37.6% done in 549.9s, 913.4s to go
# Meep progress: 75.8/200.0 = 37.9% done in 553.9s, 907.7s to go
# Meep progress: 76.45/200.0 = 38.2% done in 558.0s, 901.7s to go
# Meep progress: 77.14/200.0 = 38.6% done in 562.0s, 895.1s to go
# Meep progress: 77.705/200.0 = 38.9% done in 566.0s, 890.8s to go
# Meep progress: 78.255/200.0 = 39.1% done in 570.0s, 886.8s to go
# Meep progress: 78.71000000000001/200.0 = 39.4% done in 574.0s, 884.6s to go
# Meep progress: 79.34/200.0 = 39.7% done in 578.0s, 879.1s to go
# Meep progress: 79.815/200.0 = 39.9% done in 582.0s, 876.4s to go
# Meep progress: 80.215/200.0 = 40.1% done in 586.1s, 875.2s to go
# Meep progress: 80.705/200.0 = 40.4% done in 590.1s, 872.2s to go
# Meep progress: 81.235/200.0 = 40.6% done in 594.1s, 868.6s to go
# Meep progress: 81.83/200.0 = 40.9% done in 598.1s, 863.8s to go
# Meep progress: 82.33/200.0 = 41.2% done in 602.1s, 860.6s to go
# Meep progress: 82.83500000000001/200.0 = 41.4% done in 606.2s, 857.4s to go
# Meep progress: 83.3/200.0 = 41.6% done in 610.2s, 854.8s to go
# Meep progress: 83.935/200.0 = 42.0% done in 614.2s, 849.3s to go
# Meep progress: 84.47500000000001/200.0 = 42.2% done in 618.2s, 845.5s to go
# Meep progress: 85.055/200.0 = 42.5% done in 622.2s, 840.9s to go
# Meep progress: 85.525/200.0 = 42.8% done in 626.3s, 838.3s to go
# Meep progress: 86.05/200.0 = 43.0% done in 630.3s, 834.7s to go
# Meep progress: 86.655/200.0 = 43.3% done in 634.3s, 829.7s to go
# Meep progress: 87.13/200.0 = 43.6% done in 638.3s, 826.9s to go
# Meep progress: 87.545/200.0 = 43.8% done in 642.3s, 825.1s to go
# Meep progress: 88.05/200.0 = 44.0% done in 646.3s, 821.8s to go
# Meep progress: 88.495/200.0 = 44.2% done in 650.4s, 819.5s to go
# Meep progress: 88.995/200.0 = 44.5% done in 654.4s, 816.2s to go
# Meep progress: 89.405/200.0 = 44.7% done in 658.4s, 814.4s to go
# Meep progress: 89.905/200.0 = 45.0% done in 662.4s, 811.1s to go
# Meep progress: 90.31/200.0 = 45.2% done in 666.4s, 809.4s to go
# Meep progress: 90.8/200.0 = 45.4% done in 670.4s, 806.3s to go
# Meep progress: 91.43/200.0 = 45.7% done in 674.4s, 800.8s to go
# Meep progress: 92.04/200.0 = 46.0% done in 678.4s, 795.8s to go
# Meep progress: 92.74/200.0 = 46.4% done in 682.4s, 789.3s to go
# Meep progress: 93.395/200.0 = 46.7% done in 686.5s, 783.5s to go
# Meep progress: 93.895/200.0 = 46.9% done in 690.5s, 780.3s to go
# Meep progress: 94.365/200.0 = 47.2% done in 694.5s, 777.5s to go
# Meep progress: 94.98/200.0 = 47.5% done in 698.5s, 772.4s to go
# Meep progress: 95.51/200.0 = 47.8% done in 702.5s, 768.6s to go
# Meep progress: 96.075/200.0 = 48.0% done in 706.6s, 764.3s to go
# Meep progress: 96.64/200.0 = 48.3% done in 710.6s, 760.0s to go
# Meep progress: 97.285/200.0 = 48.6% done in 714.6s, 754.5s to go
# Meep progress: 97.83500000000001/200.0 = 48.9% done in 718.6s, 750.4s to go
# Meep progress: 98.34/200.0 = 49.2% done in 722.6s, 747.0s to go
# Meep progress: 98.935/200.0 = 49.5% done in 726.7s, 742.3s to go
# Meep progress: 99.58500000000001/200.0 = 49.8% done in 730.7s, 736.8s to go
# Meep progress: 100.145/200.0 = 50.1% done in 734.7s, 732.6s to go
# Meep progress: 100.71000000000001/200.0 = 50.4% done in 738.7s, 728.3s to go
# Meep progress: 101.375/200.0 = 50.7% done in 742.7s, 722.6s to go
# Meep progress: 101.95/200.0 = 51.0% done in 746.7s, 718.1s to go
# Meep progress: 102.5/200.0 = 51.2% done in 750.7s, 714.1s to go
# Meep progress: 103.04/200.0 = 51.5% done in 754.7s, 710.2s to go
# Meep progress: 103.58500000000001/200.0 = 51.8% done in 758.7s, 706.2s to go
# Meep progress: 104.16/200.0 = 52.1% done in 762.8s, 701.8s to go
# Meep progress: 104.745/200.0 = 52.4% done in 766.8s, 697.3s to go
# Meep progress: 105.38/200.0 = 52.7% done in 770.8s, 692.1s to go
# Meep progress: 105.935/200.0 = 53.0% done in 774.8s, 688.0s to go
# Meep progress: 106.52/200.0 = 53.3% done in 778.8s, 683.4s to go
# Meep progress: 107.015/200.0 = 53.5% done in 782.8s, 680.2s to go
# Meep progress: 107.535/200.0 = 53.8% done in 786.8s, 676.5s to go
# Meep progress: 108.095/200.0 = 54.0% done in 790.8s, 672.4s to go
# Meep progress: 108.685/200.0 = 54.3% done in 794.8s, 667.8s to go
# Meep progress: 109.175/200.0 = 54.6% done in 798.9s, 664.6s to go
# Meep progress: 109.755/200.0 = 54.9% done in 802.9s, 660.2s to go
# Meep progress: 110.46000000000001/200.0 = 55.2% done in 806.9s, 654.1s to go
# Meep progress: 111.11/200.0 = 55.6% done in 810.9s, 648.7s to go
# Meep progress: 111.645/200.0 = 55.8% done in 814.9s, 644.9s to go
# Meep progress: 112.19/200.0 = 56.1% done in 818.9s, 641.0s to go
# Meep progress: 112.775/200.0 = 56.4% done in 822.9s, 636.5s to go
# Meep progress: 113.425/200.0 = 56.7% done in 827.0s, 631.2s to go
# Meep progress: 114.02/200.0 = 57.0% done in 831.0s, 626.6s to go
# Meep progress: 114.57000000000001/200.0 = 57.3% done in 835.0s, 622.6s to go
# Meep progress: 115.05/200.0 = 57.5% done in 839.0s, 619.5s to go
# Meep progress: 115.655/200.0 = 57.8% done in 843.0s, 614.8s to go
# Meep progress: 116.28/200.0 = 58.1% done in 847.0s, 609.9s to go
# Meep progress: 116.875/200.0 = 58.4% done in 851.1s, 605.3s to go
# Meep progress: 117.46000000000001/200.0 = 58.7% done in 855.1s, 600.9s to go
# Meep progress: 118.07000000000001/200.0 = 59.0% done in 859.1s, 596.1s to go
# Meep progress: 118.675/200.0 = 59.3% done in 863.1s, 591.5s to go
# Meep progress: 119.255/200.0 = 59.6% done in 867.1s, 587.1s to go
# Meep progress: 119.805/200.0 = 59.9% done in 871.1s, 583.1s to go
# Meep progress: 120.39/200.0 = 60.2% done in 875.2s, 578.7s to go
# Meep progress: 121.02/200.0 = 60.5% done in 879.2s, 573.8s to go
# Meep progress: 121.625/200.0 = 60.8% done in 883.2s, 569.1s to go
# Meep progress: 122.26/200.0 = 61.1% done in 887.2s, 564.1s to go
# Meep progress: 122.85000000000001/200.0 = 61.4% done in 891.2s, 559.7s to go
# Meep progress: 123.385/200.0 = 61.7% done in 895.3s, 555.9s to go
# Meep progress: 123.86/200.0 = 61.9% done in 899.3s, 552.8s to go

# %%
eps_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Dielectric)
plt.figure(dpi=100)
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()

# %%
ez_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Ez)
plt.figure(dpi=100)
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.imshow(ez_data.transpose(), interpolation='spline36', cmap='RdBu', alpha=0.9)
plt.axis('off')
plt.show()
